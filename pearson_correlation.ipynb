# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import gettempdata as gt
import getmosdata as gm
import getraindata as gr
import seaborn as sns
import scipy.stats

# %%
temp=gt.get_temp_data()
temp.tempinfo()
avgtempdata=temp.avgtemp
maxtempdata=temp.maxtemp
mintempdata=temp.mintemp
mos = gm.get_mos_data()
mos.mosinfo()
mosdata = mos.mos
rain = gr.get_rain_data()
rain.raininfo()
raindata=rain.precipitation

# %%
t = pd.DataFrame(data=[],columns=['type'],index=avgtempdata.index).fillna('temp')
avgtemp = pd.concat([avgtempdata,t],axis=1)
m = pd.DataFrame(data=[],columns=['type'],index=mosdata.index).fillna('mos')
mosd = pd.concat([mosdata,m],axis=1)
r = pd.DataFrame(data=[],columns=['type'],index=raindata.index).fillna('rain')
raind = pd.concat([raindata,m],axis=1)
data=pd.concat([mosd,avgtemp,raind],axis=0)
groupdata = data.groupby(data['type'])
groupdata

# %%
k=np.zeros(209)
k=np.where(k==0,'2019','')
data= mosdata['2019']
d2019=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2018','')
data= mosdata['2018']
d2018=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2017','')
data= mosdata['2017']
d2017=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2016','')
data= mosdata['2016']
d2016=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2015','')
data= mosdata['2015']
d2015=pd.DataFrame({"mos": data, "year":k})
smosdata=pd.concat([d2019,d2018,d2017,d2016,d2015])


data= avgtempdata['2019'][96:-61]
t2019=pd.DataFrame({"temp": data})
data= avgtempdata['2018'][96:-61]
t2018=pd.DataFrame({"temp": data})
data= avgtempdata['2017'][96:-61]
t2017=pd.DataFrame({"temp": data})
data= avgtempdata['2016'][96:-61]
t2016=pd.DataFrame({"temp": data})
data= avgtempdata['2015'][96:-61]
t2015=pd.DataFrame({"temp": data})
savgtempdata=pd.concat([t2019,t2018,t2017,t2016,t2015])

data= raindata['2019'][96:-61]
r2019=pd.DataFrame({"rain": data})
data= raindata['2018'][96:-61]
r2018=pd.DataFrame({"rain": data})
data= raindata['2017'][96:-61]
r2017=pd.DataFrame({"rain": data})
data= raindata['2016'][96:-61]
r2016=pd.DataFrame({"rain": data})
data= raindata['2015'][96:-61]
r2015=pd.DataFrame({"rain": data})
sraindata=pd.concat([r2019,r2018,r2017,r2016,r2015])

data=pd.concat([savgtempdata,smosdata,sraindata],axis=1)
data
# Out:
#        temp     mos  year  rain
# 04-06   9.3     NaN  2019   0.8
# 04-07  12.6     NaN  2019   0.0
# 04-08  11.6     NaN  2019   0.0
# 04-09   9.2     NaN  2019  17.4
# 04-10   7.1     NaN  2019   5.6
# ...     ...     ...   ...   ...
# 10-27  12.1  1212.0  2015  26.5
# 10-28   9.9   252.0  2015   0.0
# 10-29   8.4   326.0  2015   0.5
# 10-30   5.4   151.0  2015   0.0
# 10-31   5.7    27.0  2015   0.0
#
# [1045 rows x 4 columns]

# %%
with sns.axes_style('white'):
    a=sns.jointplot(x="rain", y="mos",data=data,kind="hex")

# %%
with sns.axes_style('white'):
    a=sns.jointplot(x="temp", y="mos",data=data,marker="x",ci=68,kind="reg")

# %%
c = data.corr()
p=sns.clustermap(c, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

# %%
t2019 = pd.concat([mosdata['2019'], avgtempdata['2019'][96:-61]],axis=1)
c2019 = t2019.corr()
p2019=sns.clustermap(c2019, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

t2018 = pd.concat([mosdata['2018'], avgtempdata['2018'][96:-61]],axis=1)
c2018 = t2018.corr()
p2018=sns.clustermap(c2018, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

t2017 = pd.concat([mosdata['2017'], avgtempdata['2017'][96:-61]],axis=1)
c2017 = t2017.corr()
p2017=sns.clustermap(c2017, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

t2016 = pd.concat([mosdata['2016'], avgtempdata['2016'][96:-61]],axis=1)
c2016 = t2016.corr()
p2067=sns.clustermap(c2016, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

t2015 = pd.concat([mosdata['2015'], avgtempdata['2015'][96:-61]],axis=1)
c2015 = t2015.corr()
p2015=sns.clustermap(c2015, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )

# %%
pear2015=scipy.stats.pearsonr(mosdata['2015'],avgtempdata['2015'][96:-61])
pear2016=scipy.stats.pearsonr(mosdata['2016'][12:],avgtempdata['2016'][108:-61])
pear2017=scipy.stats.pearsonr(mosdata['2017'][11:],avgtempdata['2017'][107:-61])
pear2018=scipy.stats.pearsonr(mosdata['2018'][24:],avgtempdata['2018'][120:-61])
pear2019=scipy.stats.pearsonr(mosdata['2019'][10:],avgtempdata['2019'][105:-62])
a=mosdata['2015'].append(mosdata['2016'][12:].append(mosdata['2017'][11:]).append(mosdata['2018'][24:]).append(mosdata['2019'][10:]))
b=avgtempdata['2015'][96:-61].append(avgtempdata['2016'][108:-61].append(avgtempdata['2017'][107:-61].append(avgtempdata['2018'][120:-61].append(avgtempdata['2019'][105:-62]))))

pear=scipy.stats.pearsonr(a,b)

print(" 2019년 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear2019)
print(" 2018년 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear2018)
print(" 2017년 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear2017)
print(" 2016년 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear2016)
print(" 2015년 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear2015)
# Out:
#  2019년 온도-모기채집량 피어슨 상관계수 & p-value
# (0.6806696835384068, 1.9787673448809208e-28)
#  2018년 온도-모기채집량 피어슨 상관계수 & p-value
# (0.5466922220958934, 8.269247345845168e-16)
#  2017년 온도-모기채집량 피어슨 상관계수 & p-value
# (0.7864309603094826, 7.0413959293573314e-43)
#  2016년 온도-모기채집량 피어슨 상관계수 & p-value
# (0.4917012276716988, 2.180682280557163e-13)
#  2015년 온도-모기채집량 피어슨 상관계수 & p-value
# (0.6423567965648058, 1.0368222165080596e-25)

# %%
print(" 전체 온도-모기채집량 피어슨 상관계수 & p-value")
print(pear)
# Out:
#  전체 온도-모기채집량 피어슨 상관계수 & p-value
# (0.488562452513023, 2.106188969284883e-60)

# %%
pear2015=scipy.stats.spearmanr(mosdata['2015'],avgtempdata['2015'][96:-61])
pear2016=scipy.stats.spearmanr(mosdata['2016'][12:],avgtempdata['2016'][108:-61])
pear2017=scipy.stats.spearmanr(mosdata['2017'][11:],avgtempdata['2017'][107:-61])
pear2018=scipy.stats.spearmanr(mosdata['2018'][24:],avgtempdata['2018'][120:-61])
pear2019=scipy.stats.spearmanr(mosdata['2019'][10:],avgtempdata['2019'][105:-62])
a=mosdata['2015'].append(mosdata['2016'][12:].append(mosdata['2017'][11:]).append(mosdata['2018'][24:]).append(mosdata['2019'][10:]))
b=avgtempdata['2015'][96:-61].append(avgtempdata['2016'][108:-61].append(avgtempdata['2017'][107:-61].append(avgtempdata['2018'][120:-61].append(avgtempdata['2019'][105:-62]))))

pear=scipy.stats.spearmanr(a,b)

print(" 2019년 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear2019)
print(" 2018년 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear2018)
print(" 2017년 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear2017)
print(" 2016년 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear2016)
print(" 2015년 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear2015)
print(" 전체 온도-모기채집량 스피어만 상관계수 & p-value")
print(pear)
# Out:
#  2019년 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.7363651326049128, pvalue=2.875170953041383e-35)
#  2018년 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.47080138843179825, pvalue=1.3542517103148723e-11)
#  2017년 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.8198395367841886, pvalue=2.3896766600605486e-49)
#  2016년 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.6140632283957607, pvalue=8.359149125121772e-22)
#  2015년 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.744853871921313, pvalue=3.121978745556526e-38)
#  전체 온도-모기채집량 스피어만 상관계수 & p-value
# SpearmanrResult(correlation=0.628580229487237, pvalue=9.358989871556956e-110)

# %%
k=np.zeros(209)
k=np.where(k==0,'2019','')
data= mosdata['2019']
d2019=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2018','')
data= mosdata['2018']
d2018=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2017','')
data= mosdata['2017']
d2017=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2016','')
data= mosdata['2016']
d2016=pd.DataFrame({"mos": data, "year":k})
k=np.zeros(209)
k=np.where(k==0,'2015','')
data= mosdata['2015']
d2015=pd.DataFrame({"mos": data, "year":k})
smosdata=pd.concat([d2019,d2018,d2017,d2016,d2015])


data= avgtempdata['2019'][96:-61]
t2019=pd.DataFrame({"temp": data})

data= avgtempdata['2018'][96:-61]
t2018=pd.DataFrame({"temp": data})

data= avgtempdata['2017'][96:-61]
t2017=pd.DataFrame({"temp": data})

data= avgtempdata['2016'][96:-61]
t2016=pd.DataFrame({"temp": data})
data= avgtempdata['2015'][96:-61]
t2015=pd.DataFrame({"temp": data})
savgtempdata=pd.concat([t2019,t2018,t2017,t2016,t2015])

data=pd.concat([savgtempdata,smosdata],axis=1)
data
# Out:
#        temp     mos  year
# 04-06   9.3     NaN  2019
# 04-07  12.6     NaN  2019
# 04-08  11.6     NaN  2019
# 04-09   9.2     NaN  2019
# 04-10   7.1     NaN  2019
# ...     ...     ...   ...
# 10-27  12.1  1212.0  2015
# 10-28   9.9   252.0  2015
# 10-29   8.4   326.0  2015
# 10-30   5.4   151.0  2015
# 10-31   5.7    27.0  2015
#
# [1045 rows x 3 columns]

# %%
with sns.axes_style('white'):
    a=sns.jointplot(x="temp", y="mos",data=data,marker="x",ci=68,kind="reg")

# %%
with sns.axes_style('white'):
    a=sns.lmplot(x="mos", y="temp",data=data,col="year",ci=68,markers="x")

# %%
c2015 = data.corr()
p2015=sns.clustermap(c2015, 
               annot = True,      # 실제 값 화면에 나타내기
               cmap = 'RdYlBu_r',  # Red, Yellow, Blue 색상으로 표시
               vmin = -1, vmax = 1, #컬러차트 -1 ~ 1 범위로 표시
              )
